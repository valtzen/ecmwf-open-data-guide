# %% [markdown]
# # Copernicus SEAS5 — Seasonal Forecast Anomalies
#
# **Last updated:** 2026-05-09
# **Status:** 🚧 Work in progress
#
# ---
#
# This notebook is in development. See B01 for the ERA5 pattern; this notebook adapts it for seasonal data.
#
# Reference: [C3S training notebooks](https://ecmwf-projects.github.io/copernicus-training-c3s/)

# %%
# Placeholder — full implementation follows B01 pattern
import cdsapi
import earthkit.data as ekd
print('B-series notebook stub — run B01 first')
# Out:
# B-series notebook stub — run B01 first
