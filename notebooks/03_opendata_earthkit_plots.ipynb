# %% [markdown]
# ## ECMWF Open Data: Retrieval & Plotting with earthkit
#
# Setup
#
# We reuse project helpers (`_utils.py`) and keep everything in a single `./data` cache.
#
# > **Status note (July 2026):** Written against the ECMWF Free and Open Data catalogue as of mid-2026 (IFS cycle 50r1, 0.25 degree grid). An update to the Free and Open Data offering, including a move to 0.1 degree resolution, is expected later in 2026: file naming and catalogue examples here may need revisiting after that release.

# %% [markdown]
# ## 1. Learning objectives
#
# 1. Use earthkit as the single interface for both retrieval and reading/plotting
# 2. Understand IFS Cycle 50r1 changes: deprecated streams and updated MARS types
# 3. Plot global and regional (Africa) wind vectors with earthkit.plots
# 4. Visualise ENS perturbed member spread vs IFS deterministic reference
# 5. Compare AIFS vs IFS for temperature and MSLP
# 6. Produce a vertical sounding profile with CAPE/CIN and wind barbs
#
# ---
#
# ## 2. Introduction
#
# This notebook goes beyond single-file downloads. We fetch a compact but representative set of ECMWF Open Data products and use earthkit for all retrieval, reading, and plotting.
#
# **Products fetched:**
# - IFS deterministic: surface fields (2t, msl, 10u/v) + pressure levels
# - IFS ENS perturbed members: 2t time series for spread analysis
# - AIFS deterministic: same surface fields for model comparison
# - AIFS ENS control: 2t snapshot
# - IFS/AIFS wave: SWH, MWP, MWD at step 0
#
# **Prerequisites:** Notebook 01 recommended first (catalog overview, 50r1 naming)
# **Run time:** first run ~15 min (downloads ~50 MB), subsequent runs instant (cached)
# **Data:** live from data.ecmwf.int: no credentials needed

# %%
from pathlib import Path
from datetime import datetime, timedelta, timezone
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
import cartopy.crs as ccrs

# Earthkit - used for both retrieval AND reading/plotting
import earthkit.data as ekd
import earthkit.plots as ekp

# Project helpers
from _utils import get_data_dir

# Shared cache
DATA_DIR = Path(get_data_dir())
DATA_DIR.mkdir(parents=True, exist_ok=True)
print("Data cache:", DATA_DIR)
print("earthkit-data:", ekd.__version__)
print("earthkit-plots:", getattr(ekp, "__version__", "unknown"))
# Out:
# Data cache: /Users/valtze/ecmwf-open-data-guide/data
# earthkit-data: 0.19.4
# earthkit-plots: 0.6.1

# %% [markdown]
# ## 3. Preflight & downloads: pick a safe run and cache exactly what we need
#
# This one cell does **all the setup** for the rest of the notebook:
#
# - Uses **earthkit** (`ekd.from_source('ecmwf-open-data', ...)`) for all retrieval: no separate client needed
# - **Pins a safe IFS run** (00z or 12z with a small publish buffer).
#   If you already defined `fc_date`/`fc_time`, those are used. Otherwise we pick a conservative run based on UTC time.
# - **Fetches only the files used later**, saving to the shared `./data` cache:
#   - **Deterministic surface bundle**: `msl/2t/10u/10v`, **step 0** → `hres_sfc`
#   - **Deterministic 2t time series**: steps **0..24 by 3 h** → `hres_ts`
#   - **ENS 2t time series**: **PF** (perturbed, 50 members), steps **0, 6, 12, 18, 24 h** → `ifs_pf_ts`
#   - **Deterministic pressure levels**: `t/u/v/r`, **step 0** (for sounding) → `hres_pl`
#   - **Waves**: deterministic (`wave`) & ENS perturbed (`waef`, type=pf), **step 0** → `wave_det`, `wave_ens`
#   - **AIFS single**: `msl/2t`, **step 0** (for comparisons) → `aifs_sfc`
# - Uses a **"pin-or-latest"** strategy: try the pinned run first; if not yet published, **fall back to latest** so the lesson still runs.
# - Performs a **light integrity check** (opens the first GRIB message) to guard against partial/corrupt downloads; bad files are removed and retried as needed.
# - Updates `fc_date`/`fc_time` to the **actual run used** (after any fallback), so plot titles match the data.
# - Prints a short **summary** with file sizes (or "missing" if a product isn't available for that run).
#
# **Outputs/variables set**
#
# - Run info: `fc_date` (YYYYMMDD), `fc_time` ("00" or "12")
# - Paths to cached files (or `None` if unavailable):
#   `hres_sfc`, `hres_ts`, `ifs_pf_ts`, `hres_pl`, `wave_det`, `wave_ens`, `aifs_sfc`, `aifs_ens_cf`
#
# > Re-running this cell is **idempotent**: existing valid files are reused.
# > Delete files in `./data` to force a fresh download.

# %%
# === PREFLIGHT: fetch all data using earthkit (ecmwf-open-data source) ==========
#
# earthkit.data.from_source("ecmwf-open-data", ...) uses ecmwf-opendata client
# internally but provides a cleaner, unified interface for retrieval + reading.
#
# IFS Cycle 50r1 changes (12 May 2026) - all handled transparently by earthkit:
#   - stream=scda/scwv deprecated: 06z/18z now under oper/wave (client v0.3.29+)
#   - enfo/cf deprecated: IFS deterministic is now oper/fc
#   - IFS ENS perturbed suffix: enfo-pf -> enfo-ef (MARS type=pf unchanged)
#   - waef suffix: waef-cf/pf -> waef-ef (MARS type=pf, no cf in free data)
#
from pathlib import Path
from datetime import datetime, timedelta, timezone
import earthkit.data as ekd

try:
    from _utils import get_data_dir
    DATA_DIR = Path(get_data_dir())
except Exception:
    DATA_DIR = Path("data")
DATA_DIR.mkdir(parents=True, exist_ok=True)

def _ok(p) -> bool:
    try:
        p = Path(p)
        return p.exists() and p.stat().st_size > 0
    except Exception:
        return False

def _valid_grib(p) -> bool:
    try:
        ds = ekd.from_source("file", str(p))
        _ = ds[0]
        return True
    except Exception:
        try:
            Path(p).unlink(missing_ok=True)
        except Exception:
            pass
        return False

def _extract_run(path_like):
    try:
        ds = ekd.from_source("file", str(path_like))
        d = str(ds[0].metadata("date"))
        t = f"{int(ds[0].metadata('time')):02d}"
        return d, t
    except Exception:
        return None

# ---------- 1) Safe, conservative run ----------
if "fc_date" not in globals() or "fc_time" not in globals():
    now = datetime.now(timezone.utc)
    if   now.hour >= 22:  run_date, run_hour = now,                     12
    elif now.hour >= 10:  run_date, run_hour = now,                     0
    else:                 run_date, run_hour = now - timedelta(days=1), 12
    fc_date = run_date.strftime("%Y%m%d")
    fc_time = f"{run_hour:02d}"

print(f"[preflight] target run: {fc_date} {fc_time}z")

def _fetch(target: Path, **kwargs) -> Path | None:
    """
    Fetch using earthkit ecmwf-open-data source.
    Cache-first: if valid file exists, skip download.
    Tries pinned run first, falls back to latest.
    """
    target = Path(target)
    if _ok(target) and _valid_grib(target):
        return target

    for date_kw in [{"date": int(fc_date), "time": int(fc_time)}, {}]:
        try:
            ds = ekd.from_source("ecmwf-open-data", source="aws",  **kwargs, **date_kw)
            ds.save(str(target))
            if _ok(target) and _valid_grib(target):
                return target
        except Exception:
            pass

    return None

# ---------- 2) Fetch all files ----------
print("[preflight] downloading/checking...")

# IFS deterministic surface bundle (msl/2t/10u/10v), step 0
# stream=oper, type=fc - unchanged in 50r1
hres_sfc = _fetch(
    DATA_DIR / "hres_msl_2t_10uv.grib2",
    model="ifs", stream="oper", type="fc", levtype="sfc",
    step=0, param=["msl", "2t", "10u", "10v"]
)

# Pin to actual run used
if hres_sfc:
    maybe_run = _extract_run(hres_sfc)
    if maybe_run:
        fc_date, fc_time = maybe_run
        print(f"[preflight] run used: {fc_date} {fc_time}z")

# IFS deterministic 2t time series, steps 0-24h by 3h
hres_ts = _fetch(
    DATA_DIR / "hres_ts_2t.grib2",
    model="ifs", stream="oper", type="fc", levtype="sfc",
    step=list(range(0, 25, 3)), param="2t"
)

# IFS ENS perturbed 2t time series, 5 steps
# NOTE 50r1: MARS type=pf unchanged; filename suffix changed enfo-pf -> enfo-ef
ifs_pf_ts = _fetch(
    DATA_DIR / "ens_ts_2t_pf.grib2",
    model="ifs", stream="enfo", type="pf", levtype="sfc",
    step=[0, 6, 12, 18, 24],  # 50 members x 5 steps
    param="2t"
)

# NOTE: enfo/cf deprecated in 50r1
ifs_cf_ts = None  # not fetched; hres_ts is the deterministic reference

# IFS pressure levels (t/u/v/r), step 0 - sounding section
hres_pl = _fetch(
    DATA_DIR / "hres_pl_truv_step0.grib2",
    model="ifs", stream="oper", type="fc", levtype="pl",
    levelist=[1000, 925, 850, 700, 500, 300, 250, 200, 150, 100, 50],
    step=0, param=["t", "u", "v", "r"]
)

# IFS Waves deterministic, step 0
wave_det = _fetch(
    DATA_DIR / "wave_deterministic_swh_mwp_mwd.grib2",
    model="ifs", stream="wave", type="fc",
    step=0, param=["swh", "mwp", "mwd"]
)

# IFS Waves ENS perturbed, step 0
# NOTE 50r1: waef-ef contains only pf records - no cf in free open data
wave_ens = _fetch(
    DATA_DIR / "wave_ensemble_pf_swh_mwp_mwd.grib2",
    model="ifs", stream="waef", type="pf",
    step=0, param=["swh", "mwp", "mwd"]
)

# AIFS deterministic (msl/2t), step 0
try:
    aifs_sfc = _fetch(
        DATA_DIR / "aifs_det_msl_2t.grib2",
        model="aifs-single", stream="oper", type="fc", levtype="sfc",
        step=0, param=["msl", "2t"]
    )
except Exception:
    aifs_sfc = None

# AIFS ENS control (2t), step 0
# aifs-ens enfo/cf unchanged in 50r1
try:
    aifs_ens_cf = _fetch(
        DATA_DIR / "aifs_ens_cf_2t.grib2",
        model="aifs-ens", stream="enfo", type="cf", levtype="sfc",
        step=0, param="2t"
    )
except Exception:
    aifs_ens_cf = None

# ---------- 3) Summary ----------
def _size(p):
    try:
        return f"{Path(p).stat().st_size/1e6:.1f} MB" if p and _ok(p) else "(missing)"
    except Exception:
        return "(missing)"

print("\n[preflight] summary")
print("  IFS det sfc  :", hres_sfc,    _size(hres_sfc))
print("  IFS det ts   :", hres_ts,     _size(hres_ts))
print("  IFS ENS pf ts:", ifs_pf_ts,   _size(ifs_pf_ts))
print("  IFS PL       :", hres_pl,     _size(hres_pl))
print("  Wave det     :", wave_det,    _size(wave_det))
print("  Wave ENS pf  :", wave_ens,    _size(wave_ens), "(type=pf, waef-ef suffix)")
print("  AIFS det sfc :", aifs_sfc,    _size(aifs_sfc))
print("  AIFS ENS cf  :", aifs_ens_cf, _size(aifs_ens_cf))
# Out:
# [preflight] target run: 20260708 00z
# [preflight] downloading/checking...
# [preflight] run used: 20260707 1200z
#
# [preflight] summary
#   IFS det sfc  : /Users/valtze/ecmwf-open-data-guide/data/hres_msl_2t_10uv.grib2 2.7 MB
#   IFS det ts   : /Users/valtze/ecmwf-open-data-guide/data/hres_ts_2t.grib2 5.9 MB
#   IFS ENS pf ts: /Users/valtze/ecmwf-open-data-guide/data/ens_ts_2t_pf.grib2 164.8 MB
#   IFS PL       : /Users/valtze/ecmwf-open-data-guide/data/hres_pl_truv_step0.grib2 26.3 MB
#   Wave det     : /Users/valtze/ecmwf-open-data-guide/data/wave_deterministic_swh_mwp_mwd.grib2 2.7 MB
#   Wave ENS pf  : /Users/valtze/ecmwf-open-data-guide/data/wave_ensemble_pf_swh_mwp_mwd.grib2 137.0 MB (type=pf, waef-ef suffix)
#   AIFS det sfc : /Users/valtze/ecmwf-open-data-guide/data/aifs_det_msl_2t.grib2 1.1 MB
#   AIFS ENS cf  : /Users/valtze/ecmwf-open-data-guide/data/aifs_ens_cf_2t.grib2 0.6 MB

# %%
for label, path in [
    ("IFS det sfc",    hres_sfc),
    ("IFS det ts",     hres_ts),
    ("IFS ENS pf ts",  ifs_pf_ts),
    ("IFS PL",         hres_pl),
    ("Wave det",       wave_det),
    ("Wave ENS pf",    wave_ens),
    ("AIFS det sfc",   aifs_sfc),
    ("AIFS ENS cf",    aifs_ens_cf),
]:
    if path and Path(path).exists():
        ds = ekd.from_source("file", str(path))
        print(f"\n{label} ({Path(path).stat().st_size/1e6:.1f} MB):")
        try:
            print(ds.ls())
        except Exception:
            print(f"  {len(ds)} messages - file too large for ls(), showing first field:")
            print(f"  shortName={ds[0].metadata('shortName')}, type={ds[0].metadata('dataType')}, step={ds[0].metadata('step')}")
# Out:
# IFS det sfc (2.7 MB):
#   centre shortName        typeOfLevel  level  dataDate  dataTime stepRange  \
# 0   ecmf       msl            meanSea      0  20260707      1200         0
# 1   ecmf        2t  heightAboveGround      2  20260707      1200         0
# 2   ecmf       10u  heightAboveGround     10  20260707      1200         0
# 3   ecmf       10v  heightAboveGround     10  20260707      1200         0
#
#   dataType number    gridType
# 0       fc   None  regular_ll
# 1       fc   None  regular_ll
# 2       fc   None  regular_ll
# 3       fc   None  regular_ll
#
# IFS det ts (5.9 MB):
#   centre shortName        typeOfLevel  level  dataDate  dataTime stepRange  \
# 0   ecmf        2t  heightAboveGround      2  20260707      1200         0
# 1   ecmf        2t  heightAboveGround      2  20260707      1200         3
# 2   ecmf        2t  heightAboveGround      2  20260707      1200         6
# 3   ecmf        2t  heightAboveGround      2  20260707      1200         9
# 4   ecmf        2t  heightAboveGround      2  20260707      1200        12
# 5   ecmf        2t  heightAboveGround      2  20260707      1200        15
# 6   ecmf        2t  heightAboveGround      2  20260707      1200        18
# 7   ecmf        2t  heightAboveGround      2  20260707      1200        21
# 8   ecmf        2t  heightAboveGround      2  20260707      1200        24
#
#   dataType number    gridType
# 0       fc   None  regular_ll
# 1       fc   None  regular_ll
# 2       fc   None  regular_ll
# 3       fc   None  regular_ll
# 4       fc   None  regular_ll
# 5       fc   None  regular_ll
# 6       fc   None  regular_ll
# 7       fc   None  regular_ll
# 8       fc   None  regular_ll
#
# IFS ENS pf ts (164.8 MB):
#     centre shortName        typeOfLevel  level  dataDate  dataTime stepRange  \
# 0     ecmf        2t  heightAboveGround      2  20260707      1200         0
# 1     ecmf        2t  heightAboveGround      2  20260707      1200         0
# 2     ecmf        2t  heightAboveGround      2  20260707      1200         0
# 3     ecmf        2t  heightAboveGround      2  20260707      1200         0
# 4     ecmf        2t  heightAboveGround      2  20260707      1200         0
# ..     ...       ...                ...    ...       ...       ...       ...
# 245   ecmf        2t  heightAboveGround      2  20260707      1200        24
# 246   ecmf        2t  heightAboveGround      2  20260707      1200        24
# 247   ecmf        2t  heightAboveGround      2  20260707      1200        24
# 248   ecmf        2t  heightAboveGround      2  20260707      1200        24
# 249   ecmf        2t  heightAboveGround      2  20260707      1200        24
#
#     dataType  number    gridType
# 0         pf      12  regular_ll
# 1         pf      42  regular_ll
# 2         pf      11  regular_ll
# 3         pf      18  regular_ll
# 4         pf      41  regular_ll
# ..       ...     ...         ...
# 245       pf      26  regular_ll
# 246       pf      32  regular_ll
# 247       pf      25  regular_ll
# 248       pf      31  regular_ll
# 249       pf      37  regular_ll
#
# [250 rows x 10 columns]
#
# IFS PL (26.3 MB):
#    centre shortName    typeOfLevel  level  dataDate  dataTime stepRange  \
# 0    ecmf         t  isobaricInhPa   1000  20260707      1200         0
# 1    ecmf         t  isobaricInhPa    925  20260707      1200         0
# 2    ecmf         t  isobaricInhPa    850  20260707      1200         0
# 3    ecmf         t  isobaricInhPa    700  20260707      1200         0
# 4    ecmf         t  isobaricInhPa    500  20260707      1200         0
# 5    ecmf         t  isobaricInhPa    300  20260707      1200         0
# 6    ecmf         t  isobaricInhPa    250  20260707      1200         0
# 7    ecmf         t  isobaricInhPa    200  20260707      1200         0
# 8    ecmf         t  isobaricInhPa    150  20260707      1200         0
# 9    ecmf         t  isobaricInhPa    100  20260707      1200         0
# 10   ecmf         t  isobaricInhPa     50  20260707      1200         0
# 11   ecmf         u  isobaricInhPa   1000  20260707      1200         0
# 12   ecmf         u  isobaricInhPa    925  20260707      1200         0
# 13   ecmf         u  isobaricInhPa    850  20260707      1200         0
# 14   ecmf         u  isobaricInhPa    700  20260707      1200         0
# 15   ecmf         u  isobaricInhPa    500  20260707      1200         0
# 16   ecmf         u  isobaricInhPa    300  20260707      1200         0
# 17   ecmf         u  isobaricInhPa    250  20260707      1200         0
# 18   ecmf         u  isobaricInhPa    200  20260707      1200         0
# 19   ecmf         u  isobaricInhPa    150  20260707      1200         0
# 20   ecmf         u  isobaricInhPa    100  20260707      1200         0
# 21   ecmf         u  isobaricInhPa     50  20260707      1200         0
# 22   ecmf         v  isobaricInhPa   1000  20260707      1200         0
# 23   ecmf         v  isobaricInhPa    925  20260707      1200         0
# 24   ecmf         v  isobaricInhPa    850  20260707      1200         0
# 25   ecmf         v  isobaricInhPa    700  20260707      1200         0
# 26   ecmf         v  isobaricInhPa    500  20260707      1200         0
# 27   ecmf         v  isobaricInhPa    300  20260707      1200         0
# 28   ecmf         v  isobaricInhPa    250  20260707      1200         0
# 29   ecmf         v  isobaricInhPa    200  20260707      1200         0
# 30   ecmf         v  isobaricInhPa    150  20260707      1200         0
# 31   ecmf         v  isobaricInhPa    100  20260707      1200         0
# 32   ecmf         v  isobaricInhPa     50  20260707      1200         0
# 33   ecmf         r  isobaricInhPa   1000  20260707      1200         0
# 34   ecmf         r  isobaricInhPa    925  20260707      1200         0
# 35   ecmf         r  isobaricInhPa    850  20260707      1200         0
# 36   ecmf         r  isobaricInhPa    700  20260707      1200         0
# 37   ecmf         r  isobaricInhPa    500  20260707      1200         0
# 38   ecmf         r  isobaricInhPa    300  20260707      1200         0
# 39   ecmf         r  isobaricInhPa    250  20260707      1200         0
# 40   ecmf         r  isobaricInhPa    200  20260707      1200         0
# 41   ecmf         r  isobaricInhPa    150  20260707      1200         0
# 42   ecmf         r  isobaricInhPa    100  20260707      1200         0
# 43   ecmf         r  isobaricInhPa     50  20260707      1200         0
#
#    dataType number    gridType
# 0        fc   None  regular_ll
# 1        fc   None  regular_ll
# 2        fc   None  regular_ll
# 3        fc   None  regular_ll
# 4        fc   None  regular_ll
# 5        fc   None  regular_ll
# 6        fc   None  regular_ll
# 7        fc   None  regular_ll
# 8        fc   None  regular_ll
# 9        fc   None  regular_ll
# 10       fc   None  regular_ll
# 11       fc   None  regular_ll
# 12       fc   None  regular_ll
# 13       fc   None  regular_ll
# 14       fc   None  regular_ll
# 15       fc   None  regular_ll
# 16       fc   None  regular_ll
# 17       fc   None  regular_ll
# 18       fc   None  regular_ll
# 19       fc   None  regular_ll
# 20       fc   None  regular_ll
# 21       fc   None  regular_ll
# 22       fc   None  regular_ll
# 23       fc   None  regular_ll
# 24       fc   None  regular_ll
# 25       fc   None  regular_ll
# 26       fc   None  regular_ll
# 27       fc   None  regular_ll
# 28       fc   None  regular_ll
# 29       fc   None  regular_ll
# 30       fc   None  regular_ll
# 31       fc   None  regular_ll
# 32       fc   None  regular_ll
# 33       fc   None  regular_ll
# 34       fc   None  regular_ll
# 35       fc   None  regular_ll
# 36       fc   None  regular_ll
# 37       fc   None  regular_ll
# 38       fc   None  regular_ll
# 39       fc   None  regular_ll
# 40       fc   None  regular_ll
# 41       fc   None  regular_ll
# 42       fc   None  regular_ll
# 43       fc   None  regular_ll
#
# Wave det (2.7 MB):
#   centre shortName typeOfLevel  level  dataDate  dataTime stepRange dataType  \
# 0   ecmf       swh     surface      0  20260707      1200         0       fc
# 1   ecmf       mwp     surface      0  20260707      1200         0       fc
# 2   ecmf       mwd     surface      0  20260707      1200         0       fc
#
#   number    gridType
# 0   None  regular_ll
# 1   None  regular_ll
# 2   None  regular_ll
#
# Wave ENS pf (137.0 MB):
#     centre shortName typeOfLevel  level  dataDate  dataTime stepRange  \
# 0     ecmf       swh     surface      0  20260707      1200         0
# 1     ecmf       swh     surface      0  20260707      1200         0
# 2     ecmf       swh     surface      0  20260707      1200         0
# 3     ecmf       swh     surface      0  20260707      1200         0
# 4     ecmf       swh     surface      0  20260707      1200         0
# ..     ...       ...         ...    ...       ...       ...       ...
# 145   ecmf       mwd     surface      0  20260707      1200         0
# 146   ecmf       mwd     surface      0  20260707      1200         0
# 147   ecmf       mwd     surface      0  20260707      1200         0
# 148   ecmf       mwd     surface      0  20260707      1200         0
# 149   ecmf       mwd     surface      0  20260707      1200         0
#
#     dataType  number    gridType
# 0         pf      14  regular_ll
# 1         pf      44  regular_ll
# 2         pf       2  regular_ll
# 3         pf      13  regular_ll
# 4         pf      43  regular_ll
# ..       ...     ...         ...
# 145       pf      22  regular_ll
# 146       pf      27  regular_ll
# 147       pf      21  regular_ll
# 148       pf      34  regular_ll
# 149       pf      33  regular_ll
#
# [150 rows x 10 columns]
#
# AIFS det sfc (1.1 MB):
#   centre shortName        typeOfLevel  level  dataDate  dataTime stepRange  \
# 0   ecmf       msl            meanSea      0  20260707      1200         0
# 1   ecmf        2t  heightAboveGround      2  20260707      1200         0
#
#   dataType number    gridType
# 0       fc   None  regular_ll
# 1       fc   None  regular_ll
#
# AIFS ENS cf (0.6 MB):
#   centre shortName        typeOfLevel  level  dataDate  dataTime stepRange  \
# 0   ecmf        2t  heightAboveGround      2  20260707      1200         0
#
#   dataType  number    gridType
# 0       cf       0  regular_ll

# %% [markdown]
# ## 4. Inventory (quick check) + tiny sanity maps
#
# ### Why this step
# Before we dive into time series, winds, and diagnostics, we do a quick **health check** of everything the preflight cached. Think of it as a lightweight `grib_ls` plus a couple of tiny teaser maps to verify that files open cleanly and fields look sensible.
#
# ### What this cell does
# - Prints a compact **inventory** for each cached GRIB:
#   - file name & size
#   - number of GRIB messages
#   - first few `shortName` values (which variables are inside)
#   - a brief summary of detected **steps** (fast scan)
# - Draws small **global maps** for a representative scalar from each product:
#   - IFS deterministic: `2t`
#   - AIFS single: `2t`
#   - AIFS-ENS (control): `2t`
#   - Waves deterministic: `swh`
#   - Waves ENS perturbed (pf): `swh`
#
# ### What you should see
# - One text inventory block per file and up to **six tiny maps**.
# - If a file isn't available yet, you'll see **"(missing)"** and that plot is skipped.
#
# ### Tips
# - This is intentionally **quick**. Detailed winds, time series, and diagnostics come later.
# - On slower machines, reduce the internal scan limit (e.g. 300 → 120 messages) inside the inventory helper.
# - Change the mini-map domain (e.g. `"Europe"`, `"USA"`) or swap the plotted `shortName` if you prefer different variables.

# %%
# --- Step 4: Inventory (fast) + tiny sanity maps --------------------------------
from pathlib import Path
import numpy as np
import earthkit.data as ekd
from IPython.display import display

# make sure optional vars exist
aifs_ens_cf = globals().get("aifs_ens_cf", None)

ITEMS = [
    ("IFS deterministic (sfc)",                  hres_sfc),
    ("IFS deterministic 2t time series",         hres_ts),
    ("IFS ENS PF 2t time series",       ifs_pf_ts),
    ("IFS deterministic pressure levels (pl)",   hres_pl),
    ("Waves deterministic",             wave_det),
    ("Waves ENS perturbed (pf)",        wave_ens),
    ("AIFS single (sfc)",               aifs_sfc),
    ("AIFS-ENS CF (sfc/time series)",   aifs_ens_cf),
]

def _ok(p):
    try:
        p = Path(p)
        return p.exists() and p.stat().st_size > 0
    except Exception:
        return False

def describe_lite(path, max_scan=300):
    """
    Fast-ish summary without reading data arrays:
    - n messages (len(ds))
    - a few shortNames (sampled)
    - a compact step summary from first max_scan messages
    """
    try:
        ds = ekd.from_source("file", str(path))
        n = len(ds)
        shorts, steps = [], []
        for i, f in enumerate(ds):
            if i >= max_scan: break
            try:
                sn = f.metadata("shortName")
                if sn: shorts.append(sn)
            except Exception:
                pass
            try:
                st = f.metadata("step")
                if st is not None: steps.append(int(st))
            except Exception:
                pass
        # compact summaries
        shorts_show = ", ".join(sorted(set(shorts))[:8])
        if len(set(shorts)) > 8:
            shorts_show += ", ..."
        st_unique = sorted(set(steps))
        if len(st_unique) == 0:
            step_show = "-"
        elif len(st_unique) <= 6:
            step_show = ", ".join(map(str, st_unique))
        else:
            step_show = f"{st_unique[0]}...{st_unique[-1]} (#{len(st_unique)})"
        size_mb = path.stat().st_size / 1e6
        print(f"- {path.name:<36}  {size_mb:6.1f} MB  | msgs: {n:<7d} | shorts: {shorts_show or '-'} | steps: {step_show}")
    except Exception as e:
        print(f"- {path.name:<36}  (failed to inspect: {e!r})")

print("Inventory (grib_ls mimick):")
for label, p in ITEMS:
    if _ok(p):
        print(f"\n{label}:")
        describe_lite(Path(p))
    else:
        print(f"\n{label}: (missing)")

# ------------------ Tiny sanity maps (1 scalar per model) ----------------------
def _first_field(path, short=None):
    p = Path(path)
    ds = ekd.from_source("file", str(p))
    if short is not None:
        try:
            return ds.sel(shortName=short)[0]
        except Exception:
            pass
    return ds[0]

def _title_from_file(path, base):
    try:
        ds = ekd.from_source("file", str(path))
        d = str(ds[0].metadata("date")); t = f"{int(ds[0].metadata('time')):02d}"
        return f"{base}: {d} {t}z"
    except Exception:
        return base

def quick_map(path, short, base_title):
    if not _ok(path):
        print(f"{base_title}: (missing)"); return
    try:
        fld = _first_field(path, short=short)
        import earthkit.plots as ekp
        chart = ekp.Map(domain="global")
        chart.contourf(fld, auto_style=True)
        chart.coastlines(); chart.gridlines()
        chart.title(_title_from_file(path, base_title))
        chart.show()
    except Exception as e:
        print(f"{base_title}: plot failed -> {e!r}")

print("\nSanity maps:")
# 1) IFS deterministic (sfc): 2t
quick_map(hres_sfc, "2t", "IFS deterministic: 2 m temperature")


# 3) AIFS single: 2t
quick_map(aifs_sfc, "2t", "AIFS single: 2 m temperature")

# 4) AIFS-ENS CF: 2t - control member of the AIFS ensemble
# Note: AIFS ENS also has enfo-pf perturbed members (not fetched here)
# To plot ENS spread for AIFS, fetch model="aifs-ens", stream="enfo", type="pf"
# following the same pattern as IFS ENS in section 6
if _ok(aifs_ens_cf):
    quick_map(aifs_ens_cf, "2t", "AIFS-ENS control (cf): 2 m temperature")

# 5) Waves det: swh
quick_map(wave_det, "swh", "Waves deterministic: SWH")

# 6) Waves ENS perturbed (pf): swh
quick_map(wave_ens, "swh", "Waves ENS perturbed (pf): SWH")
# Out:
# Inventory (grib_ls mimick):
#
# IFS deterministic (sfc):
# - hres_msl_2t_10uv.grib2                   2.7 MB  | msgs: 4       | shorts: 10u, 10v, 2t, msl | steps: 0
#
# IFS deterministic 2t time series:
# - hres_ts_2t.grib2                         5.9 MB  | msgs: 9       | shorts: 2t | steps: 0...24 (#9)
#
# IFS ENS PF 2t time series:
# - ens_ts_2t_pf.grib2                     164.8 MB  | msgs: 250     | shorts: 2t | steps: 0, 6, 12, 18, 24
#
# IFS deterministic pressure levels (pl):
# - hres_pl_truv_step0.grib2                26.3 MB  | msgs: 44      | shorts: r, t, u, v | steps: 0
#
# Waves deterministic:
# - wave_deterministic_swh_mwp_mwd.grib2     2.7 MB  | msgs: 3       | shorts: mwd, mwp, swh | steps: 0
#
# Waves ENS perturbed (pf):
# - wave_ensemble_pf_swh_mwp_mwd.grib2     137.0 MB  | msgs: 150     | shorts: mwd, mwp, swh | steps: 0
#
# AIFS single (sfc):
# - aifs_det_msl_2t.grib2                    1.1 MB  | msgs: 2       | shorts: 2t, msl | steps: 0
#
# AIFS-ENS CF (sfc/time series):
# - aifs_ens_cf_2t.grib2                     0.6 MB  | msgs: 1       | shorts: 2t | steps: 0
#
# Sanity maps:

# %% [markdown]
# ## 5. 10-m wind vectors: barbs (global) & quiver (Africa, coloured)
#
# ### What we plot
# 10-m wind components (`10u`, `10v`) from the IFS deterministic surface bundle downloaded in the preflight.
#
# ### Two views
# - **Global barbs**: quick overview at full resolution.
# - **Quiver over Africa**: subsampled arrows; **colour and length reflect wind speed**; with gridlines and a colorbar.
#
# ### How to read it
# - `10u` / `10v` are eastward / northward components on the 0.25° grid.
# - **Quiver arrows** point **towards** the flow direction.
# - **Barbs** follow the meteorological convention (flags at the tail).
#
# ### What you can tweak
# - **Domain**: change `"global"` to `"Europe"`, `"Africa"`, `"USA"`, etc.
# - **Density** (quiver): `Subsample(nx=..., ny=...)`: larger → fewer arrows.
# - **Arrow sizing**: `scale`, `width`, and head parameters.
# - **Colour scale**: computed from robust percentiles of speed; adjust the percentiles if you want a wider/narrower palette.
# - **Background**: add `land()`, `ocean()`, coastlines, and gridlines to taste.
#
# ### Troubleshooting
# - If no arrows appear, confirm your file contains `10u` and `10v` (the IFS deterministic surface bundle does).
# - To use AIFS or ENS instead, load their datasets and select the same `shortName`s.
# - Global quiver can be heavy; keep subsampling on for performance.

# %%
def barbs_global(path, stride=15):
    p = Path(path)
    if not p.exists(): return
    ds = ekd.from_source("file", str(p))
    try:
        u = ds.sel(shortName="10u")[0].to_xarray()["10u"]
        v = ds.sel(shortName="10v")[0].to_xarray()["10v"]
    except Exception:
        print("10u/10v not found"); return

    lat = u.latitude.values[::stride]
    lon = u.longitude.values[::stride]
    U = u.values[::stride, ::stride]
    V = v.values[::stride, ::stride]

    proj = ccrs.PlateCarree()
    fig, ax = plt.subplots(figsize=(10,5), subplot_kw=dict(projection=proj))
    ax.coastlines()
    ax.barbs(lon, lat, U, V, transform=proj, length=4, linewidth=0.6)
    ax.set_title("10 m wind: global barbs"); plt.show()

def quiver_africa_colored(path, stride=5):
    p = Path(path)
    if not p.exists(): return
    ds = ekd.from_source("file", str(p))
    try:
        u = ds.sel(shortName="10u")[0].to_xarray()["10u"]
        v = ds.sel(shortName="10v")[0].to_xarray()["10v"]
    except Exception:
        print("10u/10v not found"); return

    # Crop Africa (lon -20..55, lat -35..38)
    u = u.sel(longitude=slice(-20, 55), latitude=slice(38, -35))
    v = v.sel(longitude=slice(-20, 55), latitude=slice(38, -35))

    # Subsample
    lat = u.latitude.values[::stride]
    lon = u.longitude.values[::stride]
    U = u.values[::stride, ::stride]
    V = v.values[::stride, ::stride]
    speed = np.hypot(U, V)

    proj = ccrs.PlateCarree()
    fig, ax = plt.subplots(figsize=(10,8), subplot_kw=dict(projection=proj))
    ax.set_extent([-20, 55, -35, 38], crs=proj)
    ax.coastlines()
    gl = ax.gridlines(draw_labels=True, xlocs=range(-20, 60, 10), ylocs=range(-30, 40, 10), linestyle=":", linewidth=0.5)
    q = ax.quiver(lon, lat, U, V, speed, transform=proj, scale=700, width=0.002)
    cbar = plt.colorbar(q, ax=ax, orientation="horizontal", pad=0.08)
    cbar.set_label("10 m wind speed (m s$^{-1}$)")
    ax.set_title("10 m Wind: subsampled (stride), colours & lengths reflect speed")
    plt.show()

barbs_global(hres_sfc, stride=15)
quiver_africa_colored(hres_sfc, stride=5)

# %% [markdown]
# ## 6. Time series: ENS perturbed member spread vs IFS deterministic (2 m temperature)
#
# ### Why this step
# A time series at a single location is a quick way to assess **forecast spread vs. deterministic signal**.
# We compare:
# - **50 ENS perturbed members (PF)**: faint blue lines showing the range of possible outcomes
# - **IFS deterministic**: bold green reference line
#
# > **IFS Cycle 50r1 note:** The ENS control forecast (`enfo/cf`) is deprecated. The IFS deterministic (`oper/fc`) is the direct replacement and serves as the reference line here.
#
# ### What this cell does
# - Reads `ens_ts_2t_pf.grib2` (50 ENS members) and `hres_ts_2t.grib2` (IFS det)
# - Extracts the **nearest grid point** to your chosen location
# - Plots the spaghetti ensemble spread against the deterministic reference

# %%
# Presets: choose a location by name
PRESETS = {
    # Europe
    "Paris":        (2.35,   48.86),
    "Reading":      (-0.97,  51.44),
    "Bologna":      (11.34,  44.49),
    "Riga":         (24.10,  56.96),
    # Africa
    "Addis Ababa":  (38.74,   9.03),   # Eastern Africa / ICPAC
    "Nairobi":      (36.82,  -1.29),   # Eastern Africa
    "Maputo":       (32.59, -25.97),   # Southern Africa / SADC
    "Dakar":        (-17.44, 14.69),   # Western Africa / AGRHYMET
    "Douala":       (9.70,    4.05),   # Central Africa / CAPC-AC
    "Niamey":       (2.11,   13.51),   # Western Africa / ACMAD
}
name = "Addis Ababa"
lon, lat = PRESETS[name]
print(f"Using location: {name} (lon={lon}, lat={lat})")
# Out:
# Using location: Addis Ababa (lon=38.74, lat=9.03)

# %%
def two_xarray_from_ds(ds, short):
    """Return (Dataset/DataArray) for a shortName from an Earthkit dataset."""
    xa = ds.sel(shortName=short).to_xarray()
    if isinstance(xa, xr.Dataset):
        var = list(xa.data_vars)[0]
        return xa, xa[var]
    return None, xa

def ts_pf_vs_det(pf_path, det_path, lon, lat):
    """Plot ENS perturbed member spread vs IFS deterministic reference."""

    # Load ENS PF members
    pf = None
    if pf_path and Path(pf_path).exists():
        ds_pf = ekd.from_source("file", str(pf_path))
        _, pf = two_xarray_from_ds(ds_pf, "2t")
        if pf is not None:
            pf = pf.sel(longitude=lon, latitude=lat, method="nearest")
            dims = list(pf.dims)
            if "step" in dims and "number" in dims:
                pf = pf.transpose("step", "number")
            pf = pf - 273.15

    # Load IFS deterministic
    det = None
    if det_path and Path(det_path).exists():
        ds_det = ekd.from_source("file", str(det_path))
        _, det = two_xarray_from_ds(ds_det, "2t")
        if det is not None:
            det = det.sel(longitude=lon, latitude=lat, method="nearest")
            det = det - 273.15

    def step_hours(da):
        if da is None: return None, "Forecast step (h)"
        if "step" in da.coords:
            try:
                x = (da["step"] / np.timedelta64(1, "h")).values
            except Exception:
                x = da["step"].values
            return x, "Forecast step (h)"
        return np.arange(da.shape[0]), "Index"

    fig, ax = plt.subplots(figsize=(10, 4.2))

    # ENS perturbed members - faint blue lines showing spread
    if pf is not None:
        x_pf, xlabel = step_hours(pf)
        ax.plot(x_pf, pf.values, color="tab:blue", alpha=0.15, linewidth=1, label="_members")
        ax.plot([], [], color="tab:blue", alpha=0.6, linewidth=1,
                label=f"ENS perturbed members (n={pf.shape[-1]})")

    # IFS deterministic - bold green reference
    if det is not None:
        x_det, xlabel = step_hours(det)
        ax.plot(x_det, det.values, color="tab:green", linewidth=2.2, label="IFS deterministic")

    ax.set_xlabel(xlabel)
    ax.set_ylabel("2 m Temperature (°C)")
    ax.set_title(
        f"ENS spread vs IFS deterministic - 2 m Temperature\n"
        f"Location: {lat:.1f}N, {lon:.1f}E  |  Run: {fc_date} {fc_time}z"
    )
    ax.grid(True, alpha=0.3)
    ax.legend(frameon=False, loc="best")
    plt.tight_layout()
    plt.show()

# NOTE 50r1: enfo/cf deprecated - IFS deterministic (oper/fc) is the reference
ts_pf_vs_det(ifs_pf_ts, hres_ts, lon, lat)

# %% [markdown]
# ## 7. Vertical profile (pressure levels): IFS det `t/u/v` (+ humidity), parcels & diagnostics
#
# ### Why this step
# A vertical thermodynamic/wind profile (a "sounding-style" plot) helps you read the **environment** at a point: stability, moisture, wind shear: everything that drives weather.
#
# ### What this cell does
# - Uses the preflight pressure-level file `hres_pl_truv_step0.grib2` (IFS deterministic at 0.25°) that contains:
#   - **t** (temperature), **u/v** (wind), and **r** (relative humidity)
#   - *(If `r` is missing but **q** exists, the code computes RH from q, T, and p.)*
# - Selects the **nearest grid point** to your lon/lat and sorts pressure **surface → top**.
# - Computes and plots:
#   - **T** (red) & **Td** (blue) vs **pressure (hPa)**,
#   - **Parcel curves**: **SFC**, **MU (300 hPa)**, **ML (100 hPa)**, dashed,
#   - **Wind barbs** along the pressure axis.
# - Prints key diagnostics:
#   - **CAPE/CIN** for SFC, MU, ML,
#   - **LCL** pressure & height,
#   - **0-6 km bulk shear**,
#   - **θe** at the surface and near 850 hPa.
#
# ### How to use it
# - Set your `lon, lat` (you can reuse the location from Section 6).
# - Optionally change `step_index` if you fetched multiple steps in the PL file.
#
# ### What you should see
# - A clean T/Td profile with 3 parcel tracks, wind barbs, and a printed diagnostics dict (J/kg, hPa, m/s/kt, K).
#
# ### Tweakables
# - **Parcel depths**: MU(300 hPa) and ML(100 hPa) can be edited in the code.
# - **Barb thinning**: set `barb_every` (e.g., 2 → every other level).
# - **Levels**: adjust `levelist` in the preflight if you need finer vertical detail.
# - **Step**: if your PL file has multiple steps, change `step_index`.
#
# ### Troubleshooting
# - **File not found**: ensure `hres_pl_truv_step0.grib2` exists (check preflight summary).
# - **Pressure units**: code handles both Pa and hPa automatically.
# - **Coord names**: robust selectors handle variants like `isobaricInhPa`, `level`, etc.

# %%
# Section 7: Sounding: T & Td + SFC/MU/ML parcels, wind barbs, CAPE/CIN, shear, LCL, θe
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
import earthkit.data as ekd

from metpy.units import units
from metpy.calc import (
    dewpoint_from_relative_humidity,
    lcl,
    parcel_profile_with_lcl,
    surface_based_cape_cin,
    most_unstable_cape_cin,
    mixed_layer_cape_cin,
    most_unstable_parcel,
    mixed_parcel,
    equivalent_potential_temperature,
    pressure_to_height_std,
    relative_humidity_from_specific_humidity,
)
from metpy.interpolate import interpolate_1d

def sounding_profile(
    pl_path,
    lon,
    lat,
    title_prefix="Sounding",
    step_index=0,
    barb_every=1,          # 1=no thinning, 2=every 2nd level, etc.
    figsize=(7.6, 8.6)
):
    """
    Build a MetPy-style sounding & diagnostics from an IFS deterministic PL GRIB.
    Requires t,u,v and one of r (RH %) OR q (specific humidity).
    """

    # ---- load & helpers
    src = ekd.from_source("file", str(pl_path))

    def to_da(short):
        xa = src.sel(shortName=short).to_xarray()
        return xa[list(xa.data_vars)[0]] if isinstance(xa, xr.Dataset) else xa

    # Required wind & temp
    da_t = to_da("t")   # K
    da_u = to_da("u")   # m s-1
    da_v = to_da("v")   # m s-1

    # Humidity: prefer RH ('r'), else compute from specific humidity ('q')
    have_r = True
    try:
        da_r = to_da("r")   # %
    except Exception:
        have_r = False
        da_q = to_da("q")   # kg/kg

    # ---- robust coordinate names
    def pick(coordset, *cands):
        for c in cands:
            if c in coordset: return c
        for k in coordset:
            if getattr(coordset[k], "size", 1) > 1:
                return k
        raise KeyError(f"Could not find a suitable coordinate among {list(coordset)}")

    lon_name = pick(da_t.coords, "longitude", "lon", "x")
    lat_name = pick(da_t.coords, "latitude",  "lat", "y")

    lev_name = None
    for cand in ("isobaricInhPa", "levelist", "pressure", "isobaric", "level"):
        if cand in da_t.coords:
            lev_name = cand; break
    if lev_name is None:
        exclude = {"latitude","longitude","lat","lon","time","step","valid_time"}
        lev_name = next((c for c in da_t.coords if c not in exclude and da_t[c].size > 1), None)
    if lev_name is None:
        raise ValueError("No pressure-like coordinate found in PL file.")

    # ---- nearest gridpoint & step
    def sel_point(da):
        if "step" in da.dims and da.sizes["step"] > 1:
            da = da.isel(step=step_index)
        return da.sel({lon_name: lon, lat_name: lat}, method="nearest")

    pt_T = sel_point(da_t)  # K
    pt_U = sel_point(da_u)  # m/s
    pt_V = sel_point(da_v)  # m/s
    if have_r:
        pt_R = sel_point(da_r)  # %
    else:
        pt_Q = sel_point(da_q)  # kg/kg

    # ---- pressure (hPa), sort SFC->top
    p_vals = pt_T[lev_name].values.astype(float)
    p_hpa = p_vals / 100.0 if np.nanmean(p_vals) > 2000 else p_vals
    order = np.argsort(p_hpa)[::-1]

    p   = (p_hpa[order] * units.hectopascal)
    T   = (pt_T.values[order] * units.kelvin)
    U   = (pt_U.values[order] * units('m/s'))
    V   = (pt_V.values[order] * units('m/s'))

    if have_r:
        RHf = np.clip(pt_R.values[order] / 100.0, 1e-3, 1.0) * units.dimensionless
    else:
        q   = (pt_Q.values[order] * units('kg/kg'))
        # RH (0..1) from q, T, p
        RHf = relative_humidity_from_specific_humidity(q, T, p)

    # ---- thermodynamics
    Td     = dewpoint_from_relative_humidity(T, RHf)
    thetae = equivalent_potential_temperature(p, T, Td)

    # ---------- Parcels ----------
    p_prof_sfc, _, _, Tparcel_sfc = parcel_profile_with_lcl(p, T, Td)

    mu_p, mu_T, mu_Td = most_unstable_parcel(p, T, Td, depth=300 * units.hPa)[:3]
    ml_p, ml_T, ml_Td = mixed_parcel(p, T, Td, depth=100 * units.hPa)[:3]

    def parcel_curve(seed_T, seed_Td):
        # Seed first level with parcel start; recompute parcel profile
        T_env  = T.copy();  Td_env = Td.copy()
        T_env[0], Td_env[0] = seed_T, seed_Td
        p_prof, _, _, Tparcel = parcel_profile_with_lcl(p, T_env, Td_env)
        return p_prof, Tparcel

    p_prof_mu, Tparcel_mu = parcel_curve(mu_T, mu_Td if mu_Td is not None else ml_Td)
    p_prof_ml, Tparcel_ml = parcel_curve(ml_T, ml_Td)

    # ---------- Diagnostics ----------
    cape_sfc, cin_sfc = surface_based_cape_cin(p, T, Td)
    cape_mu,  cin_mu  = most_unstable_cape_cin(p, T, Td, depth=300 * units.hPa)
    cape_ml,  cin_ml  = mixed_layer_cape_cin(p, T, Td, depth=100 * units.hPa)
    lcl_p_sfc, _      = lcl(p[0], T[0], Td[0])

    H = pressure_to_height_std(p)
    u_6 = interpolate_1d(6000 * units.m, H, U).to('m/s')
    v_6 = interpolate_1d(6000 * units.m, H, V).to('m/s')
    u_0, v_0 = U[0].to('m/s'), V[0].to('m/s')
    shear_0_6 = np.hypot((u_6 - u_0).m, (v_6 - v_0).m) * units('m/s')

    # θe at sfc and ~850 hPa
    def nearest_idx(arr, val): return int(np.argmin(np.abs(arr - val)))
    idx_850 = nearest_idx(p.to('hPa').m, 850.0)

    # ---------- Plot ----------
    P_env = p.to('hPa').m
    T_c   = T.to('degC').m
    Td_c  = Td.to('degC').m

    P_sfc = p_prof_sfc.to('hPa').m
    Tp_s  = Tparcel_sfc.to('degC').m

    P_mu  = p_prof_mu.to('hPa').m
    Tp_mu = Tparcel_mu.to('degC').m

    P_ml  = p_prof_ml.to('hPa').m
    Tp_ml = Tparcel_ml.to('degC').m

    fig, ax = plt.subplots(figsize=figsize)

    # Environment
    ax.plot(T_c,  P_env, color="tab:red",   linewidth=2, label="T")
    ax.plot(Td_c, P_env, color="tab:blue",  linewidth=2, label="Td")

    # Parcels
    ax.plot(Tp_s,  P_sfc, color="k",         linestyle="--", linewidth=1.8, label="Parcel SFC")
    ax.plot(Tp_mu, P_mu,  color="tab:green", linestyle="--", linewidth=1.8, label="Parcel MU")
    ax.plot(Tp_ml, P_ml,  color="tab:purple",linestyle="--", linewidth=1.8, label="Parcel ML")

    # LCL (surface)
    ax.axhline(lcl_p_sfc.to('hPa').m, color="k", linestyle=":", linewidth=1, alpha=0.85)

    ax.invert_yaxis()
    ax.set_ylabel("Pressure (hPa)")
    ax.set_xlabel("Temperature (°C)")
    ax.grid(True, alpha=0.3)
    ax.legend(frameon=False, loc="best")
    ax.set_title(f"{title_prefix} @ lon={lon:.2f}, lat={lat:.2f} (IFS det pl, step={step_index})")

    # Wind barbs (thinned)
    ax_barb = ax.twiny()
    ax_barb.set_xlim(0, 1); ax_barb.set_xticks([]); ax_barb.set_xlabel("")
    idx = np.arange(0, len(P_env), max(1, int(barb_every)))
    ax_barb.barbs(np.ones_like(idx), P_env[idx], U[idx].m, V[idx].m, length=6, linewidth=0.8)
    ax_barb.invert_yaxis()

    plt.tight_layout()
    plt.show()

    # ---- Diagnostics to return
    def Jkg(x): return float(x.to('J/kg').m)
    return {
        "CAPE_SFC_Jkg": Jkg(cape_sfc),
        "CIN_SFC_Jkg":  Jkg(cin_sfc),
        "CAPE_MU_Jkg":  Jkg(cape_mu),
        "CIN_MU_Jkg":   Jkg(cin_mu),
        "CAPE_ML_Jkg":  Jkg(cape_ml),
        "CIN_ML_Jkg":   Jkg(cin_ml),
        "LCL_hPa":      float(lcl_p_sfc.to('hPa').m),
        "LCL_m":        float(pressure_to_height_std(lcl_p_sfc).to('meter').m),
        "Shear_0_6km_ms": float(shear_0_6.to('m/s').m),
        "Shear_0_6km_kt": float(shear_0_6.to('knots').m),
        "ThetaE_sfc_K":   float(thetae[0].to('kelvin').m),
        "ThetaE_850_K":   float(thetae[idx_850].to('kelvin').m),
    }

# %%
# hres_pl must be the PL file you downloaded (t/u/v + r OR q)
diagnostics = sounding_profile(
    pl_path=hres_pl,
    lon=lon,
    lat=lat,
    title_prefix="Sounding",
    step_index=0,    # change if your PL file has multiple steps
    barb_every=1
)
diagnostics
# Out:
# /var/folders/nt/g4thtw252b98vppfh0bk0rnr0000gn/T/ipykernel_3060/82312812.py:202: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   "Shear_0_6km_ms": float(shear_0_6.to('m/s').m),
# /var/folders/nt/g4thtw252b98vppfh0bk0rnr0000gn/T/ipykernel_3060/82312812.py:203: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   "Shear_0_6km_kt": float(shear_0_6.to('knots').m),
# {'CAPE_SFC_Jkg': 5.354275072264902,
#  'CIN_SFC_Jkg': -507.2963454002209,
#  'CAPE_MU_Jkg': 72.69303600637008,
#  'CIN_MU_Jkg': -22.23779194085335,
#  'CAPE_ML_Jkg': 12.153706891400233,
#  'CIN_ML_Jkg': -445.1498633501869,
#  'LCL_hPa': 899.447958128345,
#  'LCL_m': 993.0239245361944,
#  'Shear_0_6km_ms': 7.317663359710719,
#  'Shear_0_6km_kt': 14.224399619308093,
#  'ThetaE_sfc_K': 343.63902218590005,
#  'ThetaE_850_K': 346.10326571745566}

# %% [markdown]
# ## 8. Difference maps: utilities & design (used by Section 9 comparisons)
#
# ### Why this step
# When comparing sources (e.g., **AIFS vs IFS**) or products (e.g., **wave ENS vs deterministic**), you need reliable, **artifact-free** differences:
# - grids must match,
# - longitudes must wrap cleanly,
# - units must be compatible,
# - colour scales must be symmetric around **0**.
#
# ### What these helpers do
# - **Load → xarray**: pick a field by `shortName` from a GRIB and return a tidy `DataArray`.
# - **Harmonise grids**: wrap longitudes to **[-180, 180)** and, when necessary, **interpolate B → A** to avoid seams.
# - **Units**: do minimal, explicit conversions only when needed (e.g., **Pa → hPa**); otherwise strip unit metadata so plotting libraries don't auto-convert.
# - **Colour scale**: center at **0** with robust symmetric limits using the **98th percentile** of |diff| (with a small floor so weak differences remain visible).
# - **Maps**: `cartopy` Plate Carree, thin coastlines/gridlines, horizontal colorbar: clean and reproducible.
#
# ### Where this is used
# The next section calls these helpers to produce three "apples-to-apples" comparisons for the pinned run:
# 1. **Waves SWH**: IFS wave ENS perturbed mean vs IFS wave deterministic
# 2. **2 m temperature**: **AIFS - IFS** (°C)
# 3. **MSLP**: **AIFS - IFS** (hPa)
#
# ### Tips
# - If a comparison shows "(missing)", the preflight likely skipped a file that wasn't published yet: re-run later or relax your preflight window.
# - Small or featureless differences (especially for waves at short lead times) are expected if both systems agree closely.
# - You can change the domain from `"global"` to a region for a closer look (e.g., `"Europe"`, `"USA"`).

# %%
# --- Section 8 helpers: load→xarray, grid harmonisation, robust difference plotting
from pathlib import Path
import numpy as np
import xarray as xr
import earthkit.data as ekd
import cartopy.crs as ccrs
import matplotlib.pyplot as plt
from matplotlib.colors import TwoSlopeNorm, Normalize
from matplotlib.cm import get_cmap

def _pick_field_da(path_like, short):
    """Open GRIB at path and return a DataArray for `short` with dims (latitude, longitude)."""
    if not path_like:
        return None
    p = Path(path_like)
    if not p.exists() or p.stat().st_size == 0:
        return None

    ds = ekd.from_source("file", str(p))
    # Prefer exact shortName match
    fld = None
    try:
        fld = ds.sel(shortName=short)[0]
    except Exception:
        try:
            fld = ds[0]
        except Exception:
            return None

    xa = fld.to_xarray()
    if isinstance(xa, xr.Dataset):
        # take the first data var if needed
        xa = xa[next(iter(xa.data_vars))]
    # normalise coord names and order
    ren = {}
    if "lon" in xa.coords: ren["lon"] = "longitude"
    if "lat" in xa.coords: ren["lat"] = "latitude"
    if ren: xa = xa.rename(ren)
    if "latitude" in xa.dims and "longitude" in xa.dims:
        xa = xa.transpose("latitude", "longitude", *[d for d in xa.dims if d not in ("latitude","longitude")])
    return xa

def _wrap_lon_180(da):
    """Wrap longitudes to [-180,180) to avoid seams, sort both axes."""
    if "longitude" not in da.coords:
        return da
    lon = xr.where(da.longitude > 180, da.longitude - 360, da.longitude)
    da = da.assign_coords(longitude=lon)
    return da.sortby(["latitude", "longitude"])

def _harmonise_grids(A, B):
    """Return (A', B') on the same lat/lon grid by wrapping and interpolating B→A if needed."""
    A = _wrap_lon_180(A)
    B = _wrap_lon_180(B)
    same_lat = np.array_equal(A.latitude.values, B.latitude.values)
    same_lon = np.array_equal(A.longitude.values, B.longitude.values)
    if not (same_lat and same_lon):
        B = B.interp(latitude=A.latitude, longitude=A.longitude)
    return A, B

def _symmetric_limits(arr, pctl=98, floor=1.0):
    """Robust symmetric limits around 0 using |values| percentiles, with a minimum floor."""
    p = np.nanpercentile(np.abs(arr), pctl)
    vmax = float(max(p, floor))
    return (-vmax, vmax)

def _plot_diff_map(diff, units_label, title, domain="global", pctl=98, floor=1.0, cmap_name="RdBu_r"):
    """Cartopy map with robust symmetric colour limits centered at 0."""
    # strip unit metadata so no unit library tries to convert
    diff = diff.copy()
    diff.attrs.pop("units", None)

    vmin, vmax = _symmetric_limits(diff.values, pctl=pctl, floor=floor)
    cmap  = get_cmap(cmap_name)

    try:
        norm = TwoSlopeNorm(vmin=vmin, vcenter=0.0, vmax=vmax)
    except Exception:
        norm = Normalize(vmin=vmin, vmax=vmax)

    proj = ccrs.PlateCarree()
    fig, ax = plt.subplots(figsize=(9.2, 4.8), subplot_kw=dict(projection=proj))
    ax.coastlines(); ax.gridlines(draw_labels=False, linewidth=0.3, alpha=0.5)

    im = diff.plot(ax=ax, transform=proj, cmap=cmap, norm=norm, add_colorbar=False)
    cb = fig.colorbar(im, ax=ax, orientation="horizontal", pad=0.05, fraction=0.05)
    cb.set_label(units_label)

    ax.set_title(title)
    plt.tight_layout(); plt.show()

    # Quick sanity line
    print(f"NaN %: {np.isnan(diff.values).mean()*100:.2f}  |  min/max: {np.nanmin(diff.values):.3g} / {np.nanmax(diff.values):.3g}")

# %% [markdown]
# ## 9a. Waves: SWH (IFS ENS mean − IFS deterministic)
#
# We compare **significant wave height (SWH)** between the **IFS wave ENS perturbed mean** and the **IFS wave deterministic** run (both at step 0).
#
# Computing the ensemble mean across all perturbed members gives a cleaner signal than a single member, and a meaningful comparison against the deterministic.
#
# > **IFS Cycle 50r1:** `waef-ef` contains only `type=pf` perturbed members: no separate wave control exists in the free open data subset post-50r1. We compute the mean across available members.
#
# - Units: meters (m)
# - Expectation: small differences at step 0 (ensemble not yet diverged); larger at longer lead times
# - Blue/red: ENS mean wetter/drier than deterministic

# %%
# --- 9a) Waves: SWH - IFS ENS perturbed mean vs IFS deterministic ---
if wave_ens and Path(wave_ens).exists() and wave_det and Path(wave_det).exists():
    import xarray as xr
    import numpy as np

    # Load wave ENS - contains 50 perturbed members
    ds_wens = ekd.from_source("file", str(wave_ens))
    xa_wens = ds_wens.to_xarray()
    swh_key = [v for v in xa_wens.data_vars if 'swh' in v.lower() or v == 'swh'][0]               if any('swh' in v.lower() or v == 'swh' for v in xa_wens.data_vars)               else list(xa_wens.data_vars)[0]
    swh_ens = xa_wens[swh_key]

    # Compute ensemble mean across member dimension
    member_dim = [d for d in swh_ens.dims if 'number' in d.lower() or 'member' in d.lower()]
    if member_dim:
        swh_ens_mean = swh_ens.isel(step=0).mean(dim=member_dim[0]) if 'step' in swh_ens.dims else swh_ens.mean(dim=member_dim[0])
    else:
        swh_ens_mean = swh_ens.isel(step=0) if 'step' in swh_ens.dims else swh_ens

    # Load wave deterministic
    B = _pick_field_da(wave_det, "swh")

    if B is None:
        print("Wave SWH not found in deterministic file; skipping.")
    else:
        # Harmonise grids
        ens_da = swh_ens_mean
        if 'lat' in ens_da.coords: ens_da = ens_da.rename({'lat': 'latitude', 'lon': 'longitude'})
        ens_da, B = _harmonise_grids(ens_da, B)

        diff_swh = (ens_da - B).assign_attrs(units="m")
        _plot_diff_map(diff_swh, "m",
                       title=f"Wave SWH (m): IFS ENS mean − IFS det: {fc_date} {fc_time}z step 0",
                       pctl=98, floor=0.1)
else:
    print("Wave files missing; skipping SWH comparison.")
# Out:
# /var/folders/nt/g4thtw252b98vppfh0bk0rnr0000gn/T/ipykernel_3060/4074965894.py:74: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap  = get_cmap(cmap_name)
# NaN %: 35.89  |  min/max: -0.0504 / 0.108

# %% [markdown]
# ## 9b. 2 m Temperature: AIFS - IFS
#
# We compare **AIFS** vs **IFS** for the **2 m temperature** at step 0. The subtraction is done after converting to **°C** (difference is identical to K, we just label °C).
#
# - Units: °C
# - Expectation: synoptic structure should match; differences are usually small-to-moderate, with regional patterns.
# - Caveat: make sure both files are the **same step** and **run time** (the preflight pins the run and step 0).

# %%
# --- 9b) 2 m Temperature: AIFS - IFS in °C (difference identical in K/°C, we label °C) ---
if aifs_sfc and Path(aifs_sfc).exists() and hres_sfc and Path(hres_sfc).exists():
    A = _pick_field_da(aifs_sfc, "2t")   # Kelvin
    B = _pick_field_da(hres_sfc, "2t")   # Kelvin
    if (A is None) or (B is None):
        print("2t not found in AIFS or IFS file; skipping.")
    else:
        A, B = _harmonise_grids(A, B)
        # convert to °C for user-facing values (difference is the same either way)
        A_c = A - 273.15
        B_c = B - 273.15
        diff_2t = (A_c - B_c).assign_attrs(units="°C")
        _plot_diff_map(diff_2t, "°C",
                       title=f"AIFS - IFS (2 m Temp, °C): {fc_date} {fc_time}z step 0",
                       pctl=98, floor=1.0)
else:
    print("AIFS or IFS deterministic surface file missing; skipping 2 m temperature comparison.")
# Out:
# /var/folders/nt/g4thtw252b98vppfh0bk0rnr0000gn/T/ipykernel_3060/4074965894.py:74: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap  = get_cmap(cmap_name)
# NaN %: 0.00  |  min/max: -12.3 / 12.6

# %% [markdown]
# ## 9c. Mean Sea Level Pressure: AIFS - IFS
#
# We compare **MSLP** (AIFS - IFS) at step 0. Fields are distributed in **Pa**, but we display the difference in **hPa**.
#
# - Units: hPa
# - Expectation: near-zero mean with coherent synoptic patterns; ±1-4 hPa differences are common at this resolution.
# - Visual scaling: symmetric, robust to outliers (98th percentile), centered at 0.

# %%
# --- 9c) MSLP: AIFS - IFS in hPa ---
if aifs_sfc and Path(aifs_sfc).exists() and hres_sfc and Path(hres_sfc).exists():
    A = _pick_field_da(aifs_sfc, "msl")  # Pa
    B = _pick_field_da(hres_sfc, "msl")  # Pa
    if (A is None) or (B is None):
        print("msl not found in AIFS or IFS file; skipping.")
    else:
        A, B = _harmonise_grids(A, B)
        A_hpa = A / 100.0
        B_hpa = B / 100.0
        diff_msl = (A_hpa - B_hpa).assign_attrs(units="hPa")
        _plot_diff_map(diff_msl, "hPa",
                       title=f"AIFS - IFS (MSL, hPa): {fc_date} {fc_time}z step 0",
                       pctl=98, floor=2.0)
else:
    print("AIFS or IFS deterministic surface file missing; skipping MSLP comparison.")
# Out:
# /var/folders/nt/g4thtw252b98vppfh0bk0rnr0000gn/T/ipykernel_3060/4074965894.py:74: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap  = get_cmap(cmap_name)
# NaN %: 0.00  |  min/max: -15.1 / 7.27

# %% [markdown]
# ## Take-home messages
#
# - The `ecmwf-opendata` client handles safe run selection, retries, and caching
# - `earthkit.data.from_source('ecmwf-open-data', ...)` is the idiomatic earthkit approach
# - IFS vs AIFS comparison is straightforward: same fields, different source
# - Africa wind quiver: set `area=[40, -20, -40, 55]` in your request
# - ENS spread plots: use `type='pf'` for perturbed members; `enfo/cf` is deprecated in IFS 50r1
# - Wave ENS: `waef-ef` contains only `pf` (perturbed) records post-50r1: compute ensemble mean for comparison
# - Section 9 comparisons: IFS ENS mean vs IFS det (waves), AIFS det vs IFS det (temp, MSLP)
#
# ---
#
# ### Next steps
# - **04**: Cloud endpoints (AWS S3 HTTP Range for single-parameter slicing)
# - **05**: ERA5 reanalysis via CDS (same earthkit workflow, historical data)
# - **06**: Seasonal forecasts (SEAS5 precipitation outlook over Africa)
#
# ### Support
# - Questions: [support.ecmwf.int](https://support.ecmwf.int)
# - earthkit docs: [earthkit.readthedocs.io](https://earthkit.readthedocs.io)
